# %%
import pytraj as pt, nglview as nv

ngl_data_dir = '../../../../ngl/data/'

# %%
view = nv.show_structure_file(ngl_data_dir + '/4UQ5.pdb')
view

# %%
view.add_unitcell(color='blue')

# %%
view.export_image(factor=1)

# %%
from IPython import display

display.Image(view._image_data)
