# %%
import nglview as nv
import pytraj as pt

view = nv.show_structure_file(nv.datafiles.PDB)
view

# %%
view.orientation = [[38.51667611570989, 2.917981053100103, 3.771810168076475],
 [-0.08780664235260573, 0.987231434620989, 0.1329063130740978],
 [-40.204999923706055, -42.970001220703125, -44.16499936580658],
 [0, 0, 0]]

# %%
view.render_image()

# %%
from IPython import display

# %%
display.Image(view._image_data, embed=True)

# %%
imw = view.get_image()

# %%
imw.width = 1000
imw
