# %%
import nglview as nv
import pytraj as pt

traj = pt.load(nv.datafiles.TRR, top=nv.datafiles.PDB)[:5]
view = nv.show_pytraj(traj)
view
# Out:
# The installed widget Javascript is the wrong version.
# The installed widget Javascript is the wrong version.

# %%
from nglview.contrib.movie import MovieMaker

download_folder = '/home/haichit/Downloads/'
movie = MovieMaker(view, download_folder=download_folder, output='my.gif')
movie.make()
# Out:
# [MoviePy] Building file my.gif with imageio
#  83%|████████▎ | 5/6 [00:01<00:00,  3.71it/s]

# %%
from IPython.display import Image

# IPython does not display gif, so trick it with png file
! mv my.gif my.png
output = 'my.png'
Image(output)
