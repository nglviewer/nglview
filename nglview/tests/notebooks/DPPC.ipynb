# %%
import nglview as nv

view = nv.NGLWidget()

view.add_component("../../../../ngl/data/Bace1Trimer-inDPPC.gro")
view

# %%
view.clear_representations()
view.add_cartoon('protein')
view.add_licorice('DPPC')

# %%
view.orientation = [[-9.685303617732382, -5.879837468852894, 51.459298911932756],
 [-0.9826154382777584, 0.047231301968619924, -0.17954415772327714],
 [-43.69759178161621, -43.27302360534668, -45.1552734375],
 [0, 0, 0]]

view.render_image()

# %%
view._display_image()
