# %%
import pytraj as pt
import nglview as nv

traj = pt.datafiles.load_trpcage()

view = nv.show_pytraj(traj)

view

# %%
traj2 = pt.datafiles.load_tz2()[:1]

view.add_trajectory(traj2)

# %%
view.orientation = [[2.3167873874511153, 14.808751556932076, -31.954239657056736],
 [-0.4225320580148787, 0.8336328282355443, 0.35570067140464995],
 [-0.3384575843811035, -0.26924943923950195, -0.7511205673217773],
 [0, 0, 0]]

# %%
view.render_image()

# %%
from nglview.utils import get_colors_from_b64

c0 = get_colors_from_b64(view._image_data)

# %%
view._display_image()

# %%
view._remove_component(component=1)

# %%
view.render_image()

# %%
c1 = get_colors_from_b64(view._image_data)

# %%
assert c0 != c1

# %%
view._display_image()
