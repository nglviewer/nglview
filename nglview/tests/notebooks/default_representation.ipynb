# %%
import nglview as nv

# %%
import pytraj as pt

traj = pt.datafiles.load_tz2_ortho()

view = nv.show_pytraj(traj)
view

# %%
view.orientation = [[33.13468849349725, 2.5516085295593074, 3.5355845875546112],
 [-0.09623351936419117, 0.9754926313134034, 0.19787176656624786],
 [-17.54050087928772, -21.045500427484512, -18.081999480724335],
 [0, 0, 0]]

# %%
view.render_image()

# %%
from IPython import display

display.Image(view._image_data)
