# %%
import nglview as nv
from traitlets import List

NGLWidget2 = type('NGLWidget', (nv.NGLWidget,), {'orientation': List().tag(sync=False)})

# %%
view = NGLWidget2()
view

# %%
view.add_component('../data/tz2.pdb')

# %%
view.orientation
# Out:
# []

# %%
view.render_image()

# %%
view._display_image()

# %%
view2 = nv.NGLWidget()
view2

# %%
view2.add_component('../data/tz2.pdb')

# %%
view2.orientation
# Out:
# [[0, 0, -12],
#  [0, 1, 0],
#  [-17.943785667419434, -19.505223751068115, -18.321021556854248],
#  [0, 0, 0]]

# %%
view2.render_image()

# %%
view2._display_image()
