# %%
import warnings
warnings.filterwarnings('ignore', category=UserWarning)

import nglview as nv
from nglview.utils import get_colors_from_b64

import pytraj, mdtraj, MDAnalysis, parmed

# %%
traj_pytraj = pytraj.load('../../../../ngl/data/1crn.pdb')
traj_mdtraj = mdtraj.load('../../../../ngl/data/1CKB.pdb')
traj_mdanalysis = MDAnalysis.Universe(nv.datafiles.PDB)
traj_parmed = parmed.load_file('../../data/tz2.pdb')

# %%
warnings.filterwarnings('ignore', category=DeprecationWarning)
view = nv.NGLWidget()
view

# %%
view.add_trajectory(traj_pytraj)

# %%
view.orientation = [[26.917992730459858, -17.03129149563592, -6.594108956741603],
 [0.3857122281547732, 0.7925147298350501, -0.4723838270372494],
 [-11.470595061779022, -10.195118427276611, -6.425104856491089],
 [0, 0, 0]]

# %%
view.render_image()

# %%
view._display_image()

# %%
colors = get_colors_from_b64(view._image_data)

assert len(colors) > 1000

# %%
view.component_0.clear()

# %%
view.render_image()

# %%
colors = get_colors_from_b64(view._image_data)

assert len(colors) == 1

# %%
view.add_trajectory(traj_mdtraj)

# %%
view.orientation = [[95.94634548386291, -32.302980507300525, 25.736028398119487],
 [0.19177993415799316, -0.15986459556068094, -0.9683304022597734],
 [-61.545670211315155, -72.09229230880737, -9.004268407821655],
 [-12.765280221143614, 12.352271354139624, -3.166815231586013]]

# %%
view.render_image()

# %%
view._display_image()

# %%
colors = get_colors_from_b64(view._image_data)

assert len(colors) > 1000

# %%
view.component_1.clear()

# %%
view.render_image()

# %%
colors = get_colors_from_b64(view._image_data)

assert len(colors) == 1

# %%
view.add_trajectory(traj_mdanalysis)

# %%
view.orientation = [[108.04466577724854, -105.60515646786185, -6.526866950053123],
 [-0.04292793866539797, 0.01781805406009217, -0.9989192705276277],
 [-61.545670211315155, -72.09229230880737, -37.97174048423767],
 [0, 0, 0]]

# %%
view.render_image()

# %%
view._display_image()

# %%
view.render_image()

# %%
colors = get_colors_from_b64(view._image_data)

assert len(colors) > 1000

# %%
view.component_2.clear()

# %%
view.render_image()

# %%
colors = get_colors_from_b64(view._image_data)

assert len(colors) == 1

# %%
view.add_trajectory(traj_parmed)

# %%
view.component_3.add_licorice()

# %%
view.render_image()

# %%
view._display_image()

# %%
view.render_image()

# %%
colors = get_colors_from_b64(view._image_data)

assert len(colors) > 1000

# %%
view.component_3.clear()

# %%
view.render_image()

# %%
colors = get_colors_from_b64(view._image_data)

assert len(colors) == 1

# %%
view[0].add_cartoon()
view[1].add_cartoon()
view[2].add_cartoon()
view[3].add_cartoon()

# %%
view.orientation = [[144.1324555350586, -140.87813044151403, -8.706893151034858],
 [-0.04292793866539797, 0.01781805406009217, -0.9989192705276277],
 [-17.943785667419434, -19.528502941131592, -17.330477714538574],
 [0, 0, 0]]
view.render_image()

# %%
colors = get_colors_from_b64(view._image_data)

assert len(colors) > 1000

# %%
view._display_image()
