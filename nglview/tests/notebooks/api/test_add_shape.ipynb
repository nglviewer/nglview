# %%
import nglview as nv
from nglview.utils import get_colors_from_b64

view = nv.NGLWidget()
view

# %%
sphere = ('sphere', [0, 0, 9], [1, 0, 0], 1.5)
arrow = ('arrow', [1, 2, 7 ], [30, 3, 3], [1, 0, 1], 1.0)
view._add_shape([sphere, arrow], name='my_shape')

# %%
view.render_image()

# %%
color = get_colors_from_b64(view._image_data)

assert len(color) > 1000

# %%
view._display_image()
