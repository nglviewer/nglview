# %%
import nglview as nv
import pytraj as pt

traj = pt.load(nv.datafiles.TRR, nv.datafiles.PDB)
view = nv.show_pytraj(traj)
view

# %%
view.orientation =  [[0, 1, 0],
                     [-40., -43., -44.2],
                     [0, 0, 0]]

# %%
view.render_image()

# %%
from PIL import Image
import io, base64

# %%
fp = io.BytesIO(base64.b64decode(view._image_data))

# %%
image = Image.open(fp)
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=3989x1200 at 0x109204390>

# %%
saved_image = Image.open("save_image.png")
saved_image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=3989x1200 at 0x10A791C88>

# %%
import numpy as np

image_arr = np.array(image)
saved_image_arr = np.array(saved_image)

# %%
image_arr.shape == saved_image_arr.shape
# Out:
# True
