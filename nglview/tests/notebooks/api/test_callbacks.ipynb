# %%
import nglview as nv

# %%
import pytraj as pt

traj = pt.load('test0.pdb')

# %% [markdown]
# # Ensure we can make `view` in function

# %%
def foo():
    import nglview
    from nglview import NGLWidget
    view = nv.NGLWidget()
    view.add_trajectory(traj)
    view.clear()
    view[0].add_cartoon('protein', color='sstruc')
    return view

# %%
view = foo()
view

# %%
view.render_image()

# %% [markdown]
# # Expected image

# %%
view._display_image()

# %% [markdown]
# # Expected bug: view won't be displayed again if making emplty NGLWidget()

# %%
view

# %% [markdown]
# # Ensure we can call add_trajectory, clear, and able to update new representations (vs default ones)

# %%
view2 = nv.NGLWidget()
view2

# %%
assert view2._ok_for_callbacks
view2.add_trajectory(traj)
assert not view2._ok_for_callbacks
view2.clear()
view2.add_licorice('protein')

# %%
assert len(view2._repr_dict['c0']) == 1
assert view2._repr_dict['c0']['0']['name'] == 'licorice'

# %% [markdown]
# # Expected image

# %%
view2.render_image()

# %%
view2._display_image()

# %% [markdown]
# # Expected bug: view won't be displayed again if making emplty NGLWidget()

# %%
view2

# %%
view3 = nv.show_pytraj(traj)
view3

# %%
# Expected: view3 will be displayed again

# %%
view3
