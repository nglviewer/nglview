# %%
import nglview as nv
from nglview.utils import get_colors_from_b64
import pytraj as pt

ala3 = pt.datafiles.load_ala3()
view = nv.show_pytraj(ala3)
view

# %%
view.render_image()

# %%
color = get_colors_from_b64(view._image_data)
assert len(color) > 1000
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-4-4a49e560cf25> in <module>()
#       1 color = get_colors_from_b64(view._image_data)
# ----> 2 assert len(color) > 1000
#
# AssertionError:

# %%
view._display_image()
