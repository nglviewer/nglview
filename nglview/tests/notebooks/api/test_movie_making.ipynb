# %%
import pytraj
import nglview as nv

traj = pytraj.datafiles.load_trpcage()
print(traj)
view = nv.show_pytraj(traj, default=False)
view.center()
view.add_licorice(color='blue')
view
# Out:
# pytraj.TrajectoryIterator, 38 frames:
# Size: 0.000258 (GB)
# <Topology: 304 atoms, 20 residues, 1 mols, non-PBC>
# NGLWidget(max_frame=37)
# t:  13%|█▎        | 4/30 [00:00<00:00, 38.16it/s, now=None]
# MoviePy - Building file ./test.gif with imageio.
# t:   6%|▌         | 4/67 [00:00<00:01, 37.98it/s, now=None]
# MoviePy - Building file ./test.gif with imageio.

# %%
from nglview.contrib.movie import MovieMaker

maker = MovieMaker(view, in_memory=True, timeout=0.5)

# %%
maker.output = './test.gif'

# %%
view._movie = maker

# %%
maker._progress
# Out:
# IntProgress(value=0, max=37)

# %%
maker._progress.value, maker._progress.max
# Out:
# (36, 37)

# %%
maker._iframe = iter(range(37))
i = next(maker._iframe)
view._set_coordinates(i, movie_making=True)

# %%
from IPython.display import Image

# %%
view.on_msg??

# %%
Image("./test.gif")
