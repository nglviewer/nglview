# %%
import nglview as nv

view = nv.show_structure_file(nv.datafiles.PDB)
view

# %%
c0 = view[0]
c0

# %%
c0.add_rope()

# %%
view.orientation = [[49.263046173622854, 43.19292654871005, -7.469161104683917],
 [-0.6436678628718128, 0.7553751964458728, 0.12288203652444658],
 [-40.204999923706055, -42.970001220703125, -44.16499936580658],
 [0, 0, 0]]

view.render_image()

# %%
view._display_image()
