# %%
import pytraj as pt, nglview as nv

traj = pt.load('../../../../ngl/data/3pqr.pdb')
view = nv.show_pytraj(traj)
view

# %%
fn = '../../../../ngl/data/3pqr.ccp4.gz'

# !cp $fn .

# %%
view._load_data('3pqr.ccp4.gz')

# %%
view._clear_repr(component=1)
view.add_surface(component=1, color='blue', opacity=0.4, wireframe=True)

# %%
view.render_image(factor=1)

# %%
from IPython import display

display.Image(view._image_data)
