# %%
import nglview as nv

view = nv.NGLWidget()
view

# %%
view._n_dragged_files
# Out:
# 1

# %%
view._ngl_component_ids
# Out:
# [UUID('15e05ac4-682d-4c13-89e7-a41a4fcfdaba')]

# %%
view._js_console()
