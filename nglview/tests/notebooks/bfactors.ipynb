# %%
import nglview as nv

view = nv.NGLWidget()

view.add_component("../../../../ngl/data/1u19.pdb")
view

# %%
view.clear_representations()
view.add_tube(':A', color_scheme='bfactor')
view.add_ball_and_stick(':A and sidechainAttached', color_scheme='bfactor')

# %%
view.orientation = [[23.331574837194047, -57.049382321850885, -16.191381572965426],
 [-0.6882651818711428, -0.5834611121103164, 0.4311196702528335],
 [-49.06758987903595, -12.067293167114258, -1.6973762512207031],
 [-5.8185208736112655, -0.8720396841846634, 13.299963318257314]]

view.render_image()

# %%
view._display_image()
