# %%
import nglview as nv
import parmed as pmd
import pytraj as pt

# %%
traj = pt.datafiles.load_tz2()
traj.save("test.pdb", overwrite=True, options='component')

# %%
parm = pmd.load_file("test.pdb")
view = nv.show_parmed(parm) # should show only 1st component, others will be shown as trajectory
view.clear_representations()
view.add_ball_and_stick('not hydrogen')
view

# %%
view.orientation = [[-27.395171928065338, 7.199118094566633, -28.494831185373354],
 [-0.603828620618103, 0.4093846847991181, 0.6839555371326158],
 [0.3269999027252197, 1.0344996452331543, 0.6119999885559082],
 [0, 0, 0]]

# %%
view.export_image()

# %%
from IPython import display

display.Image(view._image_data)
