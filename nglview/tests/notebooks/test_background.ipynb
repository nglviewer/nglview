# %%
import nglview as nv

view = nv.show_structure_file(nv.datafiles.PDB)
view

# %%
view.background = 'black'

# %%
view._get_full_params()

# %%
msg = view._ngl_msg
assert msg['backgroundColor']['value'] == 'black'

# %%
view.render_image()

# %%
view._display_image()
